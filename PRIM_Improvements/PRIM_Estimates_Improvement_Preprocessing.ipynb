# %%
from Utils.util_functions import *
from Utils.data_generators import *
from Utils.util_data_preprocessing import *
from Utils.util_plotting import visualize_precision_and_recall
number_of_repeats = 50
package = 'prim'
# Out:
# /Users/inagege/Documents/00_Uni/Bachelorarbeit/ImprovingSubgroupDiscovery/venv/lib/python3.9/site-packages/ema_workbench/em_framework/evaluators.py:59: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/inagege/Documents/00_Uni/Bachelorarbeit/ImprovingSubgroupDiscovery/venv/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# /Users/inagege/Documents/00_Uni/Bachelorarbeit/ImprovingSubgroupDiscovery/venv/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# ...

# %%
#baseline normal dataset, not modified
prec_test, prec_train, rec_test, rec_train = get_precision_and_recall_train_test(number_of_repeats, calculate_y_oakley_ohagan2004, package, None, 15)

visualize_precision_and_recall(prec_train, rec_train, prec_test, rec_test, 'train', 'test')
# Out:
# experiment 50/50
# <module 'matplotlib.pyplot' from '/Users/inagege/Documents/00_Uni/Bachelorarbeit/ImprovingSubgroupDiscovery/venv/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
prec_test, prec_train, rec_test, rec_train = get_precision_and_recall_train_test(number_of_repeats, calculate_y_oakley_ohagan2004, package, [outlier_detection_z_score], 15)

visualize_precision_and_recall(prec_train, rec_train, prec_test, rec_test, 'train', 'test')
# Out:
# experiment 50/50
# <module 'matplotlib.pyplot' from '/Users/inagege/Documents/00_Uni/Bachelorarbeit/ImprovingSubgroupDiscovery/venv/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
prec_test, prec_train, rec_test, rec_train = get_precision_and_recall_train_test(number_of_repeats, calculate_y_oakley_ohagan2004, package, [discretize_with_kbins], 15)

visualize_precision_and_recall(prec_train, rec_train, prec_test, rec_test, 'train', 'test')
# Out:
# experiment 50/50
# <module 'matplotlib.pyplot' from '/Users/inagege/Documents/00_Uni/Bachelorarbeit/ImprovingSubgroupDiscovery/venv/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
prec_test, prec_train, rec_test, rec_train = get_precision_and_recall_train_test(number_of_repeats, calculate_y_oakley_ohagan2004, package, [scaling_zscore], 15)

visualize_precision_and_recall(prec_train, rec_train, prec_test, rec_test, 'train', 'test')
# Out:
# experiment 50/50
# <module 'matplotlib.pyplot' from '/Users/inagege/Documents/00_Uni/Bachelorarbeit/ImprovingSubgroupDiscovery/venv/lib/python3.9/site-packages/matplotlib/pyplot.py'>
