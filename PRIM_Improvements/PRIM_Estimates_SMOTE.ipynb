# %%
from Utils.util_functions import *
from Utils.data_generators import *
from Utils.util_data_preprocessing import *
from Utils.util_plotting import *
number_of_repeats = 10
package = 'prim'
import warnings
warnings.filterwarnings('ignore')

# %%
visualize_precision_all_boxes(number_of_repeats, package, 20, [add_data_with_smote_dtc], calculate_y_moon2010)
# Out:
# experiment 10/10
# <module 'matplotlib.pyplot' from '/Users/inagege/Documents/00_Uni/Bachelorarbeit/ImprovingSubgroupDiscovery/venv/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
visualize_precision_all_boxes(number_of_repeats, package, 20, [add_data_with_smote], calculate_y_moon2010)
# Out:
# experiment 50/50
# <module 'matplotlib.pyplot' from '/Users/inagege/Documents/00_Uni/Bachelorarbeit/ImprovingSubgroupDiscovery/venv/lib/python3.9/site-packages/matplotlib/pyplot.py'>
